# %%
import kagglehub

path = kagglehub.dataset_download("cynthiarempel/amazon-us-customer-reviews-dataset")

print(path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/cynthiarempel/amazon-us-customer-reviews-dataset?dataset_version_number=9...
# 100%|██████████| 21.0G/21.0G [03:48<00:00, 98.5MB/s]
# Extracting files...
# /root/.cache/kagglehub/datasets/cynthiarempel/amazon-us-customer-reviews-dataset/versions/9

# %%
import pandas as pd
import os

# Define dataset path
dataset_path = "/root/.cache/kagglehub/datasets/cynthiarempel/amazon-us-customer-reviews-dataset/versions/9"


files = [f for f in os.listdir(dataset_path)]
print("Files in dataset:", files)
# Out:
# Files in dataset: ['amazon_reviews_us_Mobile_Apps_v1_00.tsv', 'amazon_reviews_us_Sports_v1_00.tsv', 'amazon_reviews_us_Software_v1_00.tsv', 'amazon_reviews_us_Toys_v1_00.tsv', 'amazon_reviews_us_Gift_Card_v1_00.tsv', 'amazon_reviews_us_Musical_Instruments_v1_00.tsv', 'amazon_reviews_us_Books_v1_02.tsv', 'amazon_reviews_us_Health_Personal_Care_v1_00.tsv', 'amazon_reviews_us_Tools_v1_00.tsv', 'amazon_reviews_us_Automotive_v1_00.tsv', 'amazon_reviews_us_Digital_Software_v1_00.tsv', 'amazon_reviews_us_Pet_Products_v1_00.tsv', 'amazon_reviews_us_Grocery_v1_00.tsv', 'amazon_reviews_us_Shoes_v1_00.tsv', 'amazon_reviews_us_Music_v1_00.tsv', 'amazon_reviews_us_Video_DVD_v1_00.tsv', 'amazon_reviews_us_Outdoors_v1_00.tsv', 'amazon_reviews_us_Electronics_v1_00.tsv', 'amazon_reviews_us_Mobile_Electronics_v1_00.tsv', 'amazon_reviews_us_Digital_Video_Download_v1_00.tsv', 'amazon_reviews_us_Furniture_v1_00.tsv', 'amazon_reviews_us_Watches_v1_00.tsv', 'amazon_reviews_us_Camera_v1_00.tsv', 'amazon_reviews_us_Video_v1_00.tsv', 'amazon_reviews_us_Digital_Ebook_Purchase_v1_01.tsv', 'amazon_reviews_us_Video_Games_v1_00.tsv', 'amazon_reviews_us_Baby_v1_00.tsv', 'amazon_reviews_us_Apparel_v1_00.tsv', 'amazon_reviews_us_Personal_Care_Appliances_v1_00.tsv', 'amazon_reviews_us_PC_v1_00.tsv', 'amazon_reviews_multilingual_US_v1_00.tsv', 'amazon_reviews_us_Digital_Music_Purchase_v1_00.tsv', 'amazon_reviews_us_Wireless_v1_00.tsv', 'amazon_reviews_us_Beauty_v1_00.tsv', 'amazon_reviews_us_Major_Appliances_v1_00.tsv', 'amazon_reviews_us_Digital_Video_Games_v1_00.tsv', 'amazon_reviews_us_Office_Products_v1_00.tsv']

# %%
if files:
    # MusicalInstruments = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Musical_Instruments_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Books = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Books_v1_02.tsv'), sep='\t', on_bad_lines='warn')
    # HealthPersonalCare = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Health_Personal_Care_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Tools = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Tools_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Automotive = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Automotive_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # DigitalSoftware = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Digital_Software_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # PetProducts = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Pet_Products_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Grocery = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Grocery_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Shoes = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Shoes_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Music = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Music_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # VideoDVD = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Video_DVD_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Outdoors = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Outdoors_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Electronics = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Electronics_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # MobileElectronics = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Mobile_Electronics_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # DigitalVideoDownload = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Digital_Video_Download_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Furniture = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Furniture_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Watches = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Watches_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Camera = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Camera_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Video = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Video_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # DigitalEbookPurchase = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Digital_Ebook_Purchase_v1_01.tsv'), sep='\t', on_bad_lines='warn')
    # VideoGames = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Video_Games_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Baby = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Baby_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Apparel = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Apparel_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # PersonalCareAppliances = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Personal_Care_Appliances_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # PC = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_PC_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # MultilingualUS = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_multilingual_US_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # DigitalMusicPurchase = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Digital_Music_Purchase_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Wireless = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Wireless_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # Beauty = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Beauty_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # MajorAppliances = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Major_Appliances_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # DigitalVideoGames = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Digital_Video_Games_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    # OfficeProducts = pd.read_csv(os.path.join(dataset_path, 'amazon_reviews_us_Office_Products_v1_00.tsv'), sep='\t', on_bad_lines='warn')
    MobileApps = pd.read_csv(os.path.join(dataset_path, files[0]), sep='\t', on_bad_lines='warn')
    Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
    Software = pd.read_csv(os.path.join(dataset_path, files[2]), sep='\t', on_bad_lines='warn')

else:
    print("No TSV files found in the dataset directory.")
# Out:
# <ipython-input-6-69b413d59848>:3: ParserWarning: Skipping line 110774: expected 15 fields, saw 22
#
#   MobileApps = pd.read_csv(os.path.join(dataset_path, files[0]), sep='\t', on_bad_lines='warn')  # Added on_bad_lines='warn'
# <ipython-input-6-69b413d59848>:3: ParserWarning: Skipping line 1973406: expected 15 fields, saw 22
# Skipping line 2025322: expected 15 fields, saw 22
#
#   MobileApps = pd.read_csv(os.path.join(dataset_path, files[0]), sep='\t', on_bad_lines='warn')  # Added on_bad_lines='warn'
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 7549: expected 15 fields, saw 22
# Skipping line 27856: expected 15 fields, saw 22
# Skipping line 53399: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 76073: expected 15 fields, saw 22
# Skipping line 89612: expected 15 fields, saw 22
# Skipping line 93502: expected 15 fields, saw 22
# Skipping line 96533: expected 15 fields, saw 22
# Skipping line 107777: expected 15 fields, saw 22
# Skipping line 114290: expected 15 fields, saw 22
# Skipping line 118937: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 175061: expected 15 fields, saw 22
# Skipping line 185159: expected 15 fields, saw 22
# Skipping line 191448: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 217523: expected 15 fields, saw 22
# Skipping line 217618: expected 15 fields, saw 22
# Skipping line 238480: expected 15 fields, saw 22
# Skipping line 242797: expected 15 fields, saw 22
# Skipping line 258855: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 274223: expected 15 fields, saw 22
# Skipping line 284977: expected 15 fields, saw 22
# Skipping line 292275: expected 15 fields, saw 22
# Skipping line 308205: expected 15 fields, saw 22
# Skipping line 316345: expected 15 fields, saw 22
# Skipping line 319263: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 346649: expected 15 fields, saw 22
# Skipping line 358085: expected 15 fields, saw 22
# Skipping line 367296: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 401531: expected 15 fields, saw 22
# Skipping line 418883: expected 15 fields, saw 22
# Skipping line 425090: expected 15 fields, saw 22
# Skipping line 426609: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 477418: expected 15 fields, saw 22
# Skipping line 478435: expected 15 fields, saw 22
# Skipping line 482297: expected 15 fields, saw 22
# Skipping line 486579: expected 15 fields, saw 22
# Skipping line 498280: expected 15 fields, saw 22
# Skipping line 514041: expected 15 fields, saw 22
# Skipping line 524280: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 525919: expected 15 fields, saw 22
# Skipping line 528040: expected 15 fields, saw 22
# Skipping line 530763: expected 15 fields, saw 22
# Skipping line 535716: expected 15 fields, saw 22
# Skipping line 537226: expected 15 fields, saw 22
# Skipping line 537298: expected 15 fields, saw 22
# Skipping line 538452: expected 15 fields, saw 22
# Skipping line 542895: expected 15 fields, saw 22
# Skipping line 563939: expected 15 fields, saw 22
# Skipping line 568311: expected 15 fields, saw 22
# Skipping line 578715: expected 15 fields, saw 22
# Skipping line 584889: expected 15 fields, saw 22
# Skipping line 587404: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 594445: expected 15 fields, saw 22
# Skipping line 600835: expected 15 fields, saw 22
# Skipping line 602086: expected 15 fields, saw 22
# Skipping line 610689: expected 15 fields, saw 22
# Skipping line 615276: expected 15 fields, saw 22
# Skipping line 622154: expected 15 fields, saw 22
# Skipping line 628440: expected 15 fields, saw 22
# Skipping line 631600: expected 15 fields, saw 22
# Skipping line 636387: expected 15 fields, saw 22
# Skipping line 638400: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 660741: expected 15 fields, saw 22
# Skipping line 665127: expected 15 fields, saw 22
# Skipping line 666026: expected 15 fields, saw 22
# Skipping line 676698: expected 15 fields, saw 22
# Skipping line 697971: expected 15 fields, saw 22
# Skipping line 699669: expected 15 fields, saw 22
# Skipping line 700379: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 741370: expected 15 fields, saw 22
# Skipping line 741589: expected 15 fields, saw 22
# Skipping line 758752: expected 15 fields, saw 22
# Skipping line 781241: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 793782: expected 15 fields, saw 22
# Skipping line 795108: expected 15 fields, saw 22
# Skipping line 818334: expected 15 fields, saw 22
# Skipping line 822690: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 855009: expected 15 fields, saw 22
# Skipping line 870760: expected 15 fields, saw 22
# Skipping line 891467: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 945450: expected 15 fields, saw 22
# Skipping line 949785: expected 15 fields, saw 22
# Skipping line 958534: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1006147: expected 15 fields, saw 22
# Skipping line 1020875: expected 15 fields, saw 22
# Skipping line 1027474: expected 15 fields, saw 22
# Skipping line 1033688: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1056719: expected 15 fields, saw 22
# Skipping line 1067438: expected 15 fields, saw 22
# Skipping line 1079099: expected 15 fields, saw 22
# Skipping line 1085814: expected 15 fields, saw 22
# Skipping line 1112836: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1124957: expected 15 fields, saw 22
# Skipping line 1138765: expected 15 fields, saw 22
# Skipping line 1148270: expected 15 fields, saw 22
# Skipping line 1160930: expected 15 fields, saw 22
# Skipping line 1162655: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1192443: expected 15 fields, saw 22
# Skipping line 1229660: expected 15 fields, saw 22
# Skipping line 1244131: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1250699: expected 15 fields, saw 22
# Skipping line 1269442: expected 15 fields, saw 22
# Skipping line 1279923: expected 15 fields, saw 22
# Skipping line 1282927: expected 15 fields, saw 22
# Skipping line 1286341: expected 15 fields, saw 22
# Skipping line 1301270: expected 15 fields, saw 22
# Skipping line 1306255: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1340306: expected 15 fields, saw 22
# Skipping line 1358550: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1382569: expected 15 fields, saw 22
# Skipping line 1390333: expected 15 fields, saw 22
# Skipping line 1411659: expected 15 fields, saw 22
# Skipping line 1440802: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1442783: expected 15 fields, saw 22
# Skipping line 1488812: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1511179: expected 15 fields, saw 22
# Skipping line 1518267: expected 15 fields, saw 22
# Skipping line 1539821: expected 15 fields, saw 22
# Skipping line 1542802: expected 15 fields, saw 22
# Skipping line 1548443: expected 15 fields, saw 22
# Skipping line 1549102: expected 15 fields, saw 22
# Skipping line 1557671: expected 15 fields, saw 22
# Skipping line 1560717: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1583031: expected 15 fields, saw 22
# Skipping line 1589830: expected 15 fields, saw 22
# Skipping line 1593954: expected 15 fields, saw 22
# Skipping line 1619714: expected 15 fields, saw 22
# Skipping line 1626865: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1640894: expected 15 fields, saw 22
# Skipping line 1671105: expected 15 fields, saw 22
# Skipping line 1682719: expected 15 fields, saw 22
# Skipping line 1698705: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1709202: expected 15 fields, saw 22
# Skipping line 1732031: expected 15 fields, saw 22
# Skipping line 1753028: expected 15 fields, saw 22
# Skipping line 1757021: expected 15 fields, saw 22
# Skipping line 1759784: expected 15 fields, saw 22
# Skipping line 1765336: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1787006: expected 15 fields, saw 22
# Skipping line 1799108: expected 15 fields, saw 22
# Skipping line 1800352: expected 15 fields, saw 22
# Skipping line 1820265: expected 15 fields, saw 22
# Skipping line 1829829: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1836210: expected 15 fields, saw 22
# Skipping line 1837913: expected 15 fields, saw 22
# Skipping line 1838322: expected 15 fields, saw 22
# Skipping line 1850799: expected 15 fields, saw 22
# Skipping line 1851660: expected 15 fields, saw 22
# Skipping line 1851760: expected 15 fields, saw 22
# Skipping line 1856953: expected 15 fields, saw 22
# Skipping line 1877331: expected 15 fields, saw 22
# Skipping line 1879194: expected 15 fields, saw 22
# Skipping line 1885539: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1914602: expected 15 fields, saw 22
# Skipping line 1920033: expected 15 fields, saw 22
# Skipping line 1920128: expected 15 fields, saw 22
# Skipping line 1928420: expected 15 fields, saw 22
# Skipping line 1932534: expected 15 fields, saw 22
# Skipping line 1938472: expected 15 fields, saw 22
# Skipping line 1955911: expected 15 fields, saw 22
# Skipping line 1957872: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 1981562: expected 15 fields, saw 22
# Skipping line 2018197: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 2036017: expected 15 fields, saw 22
# Skipping line 2057336: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 2115217: expected 15 fields, saw 22
# Skipping line 2123227: expected 15 fields, saw 22
# Skipping line 2139547: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 2180195: expected 15 fields, saw 22
# Skipping line 2227967: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 2239370: expected 15 fields, saw 22
# Skipping line 2248833: expected 15 fields, saw 22
# Skipping line 2270257: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 2294088: expected 15 fields, saw 22
# Skipping line 2339075: expected 15 fields, saw 22
# Skipping line 2341949: expected 15 fields, saw 22
# Skipping line 2355932: expected 15 fields, saw 22
# Skipping line 2358472: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 2380375: expected 15 fields, saw 22
# Skipping line 2421317: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 2427097: expected 15 fields, saw 22
# Skipping line 2430168: expected 15 fields, saw 22
# Skipping line 2433981: expected 15 fields, saw 22
# Skipping line 2435256: expected 15 fields, saw 22
# Skipping line 2459832: expected 15 fields, saw 22
# Skipping line 2461658: expected 15 fields, saw 22
# Skipping line 2488261: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 2511271: expected 15 fields, saw 22
# Skipping line 2515564: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 2739141: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 2903749: expected 15 fields, saw 22
# Skipping line 2934812: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 3005263: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 3312771: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 3362891: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 3522495: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 3580053: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 4278901: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 4488253: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: ParserWarning: Skipping line 4775463: expected 15 fields, saw 22
#
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   Sports = pd.read_csv(os.path.join(dataset_path, files[1]), sep='\t', on_bad_lines='warn')
# <ipython-input-6-69b413d59848>:5: ParserWarning: Skipping line 8021: expected 15 fields, saw 22
# Skipping line 34886: expected 15 fields, saw 22
# Skipping line 49286: expected 15 fields, saw 22
#
#   Software = pd.read_csv(os.path.join(dataset_path, files[2]), sep='\t', on_bad_lines='warn')

# %%
MobileApps.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US      1774101  R3PMQXEVYR4ZT1  B00DVKOYBM       263046246
# 1          US     13679234  R1I1K3EO98EMUV  B00R1IA4RS       128868854
# 2          US     15056632  R3K23URSI2MY42  B01069LGHK       955481764
# 3          US     52477711   RH2P770T10X38  B00X64ZKM0       455029830
# 4          US     15021042   RV9YBAW8CWFYN  B00KIZO238       685358159
#
#                                        product_title product_category  \
# 0                                        8 Ball Pool      Mobile_Apps
# 1                     Christmas Cookie - Fun Match 3      Mobile_Apps
# 2  Relax Melodies Premium: A White Noise Ambience...      Mobile_Apps
# 3                                 Star Trek™ Trexels      Mobile_Apps
# 4                                     Weather Friend      Mobile_Apps
#
#    star_rating  helpful_votes  total_votes vine verified_purchase  \
# 0            3              0            0    N                 Y
# 1            5              0            0    N                 Y
# 2            5              4            4    N                 Y
# 3            5              0            0    N                 Y
# 4            1              0            0    N                 Y
#
#   review_headline                                        review_body  \
# 0             Fun  It is a fun game but sometimes hard to control...
# 1      Five Stars  Fun cute game.  Similar to other match 3 games...
# 2     Great app !  It's a very nice app , you would pay quite a b...
# 3         awesome  I am a huge star trek fan and this game is ama...
# 4  Don't like it.  I get better information from one of the free ...
#
#   review_date
# 0  2015-08-31
# 1  2015-08-31
# 2  2015-08-31
# 3  2015-08-31
# 4  2015-08-31
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['customer_id'].plot(kind='hist', bins=20, title='customer_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['product_parent'].plot(kind='hist', bins=20, title='product_parent')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['star_rating'].plot(kind='hist', bins=20, title='star_rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['helpful_votes'].plot(kind='hist', bins=20, title='helpful_votes')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('review_id').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_5.groupby('product_id').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_6.groupby('product_title').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_7.groupby('review_headline').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='customer_id', y='product_parent', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='product_parent', y='star_rating', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10.plot(kind='scatter', x='star_rating', y='helpful_votes', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11.plot(kind='scatter', x='helpful_votes', y='total_votes', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['review_date']
#   ys = series['customer_id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('review_date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('review_id')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='review_id', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('review_date')
# _ = plt.ylabel('customer_id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['review_date']
#   ys = series['customer_id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('review_date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('product_id')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='product_id', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('review_date')
# _ = plt.ylabel('customer_id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['review_date']
#   ys = series['customer_id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('review_date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('product_title')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='product_title', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('review_date')
# _ = plt.ylabel('customer_id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['review_date']
#   ys = series['customer_id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_15.sort_values('review_date', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('review_headline')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='review_headline', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('review_date')
# _ = plt.ylabel('customer_id')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['customer_id'].plot(kind='line', figsize=(8, 4), title='customer_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['product_parent'].plot(kind='line', figsize=(8, 4), title='product_parent')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['star_rating'].plot(kind='line', figsize=(8, 4), title='star_rating')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_19['helpful_votes'].plot(kind='line', figsize=(8, 4), title='helpful_votes')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['product_id'].value_counts()
#     for x_label, grp in _df_20.groupby('review_id')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('review_id')
# _ = plt.ylabel('product_id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['product_title'].value_counts()
#     for x_label, grp in _df_21.groupby('product_id')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('product_id')
# _ = plt.ylabel('product_title')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['review_headline'].value_counts()
#     for x_label, grp in _df_22.groupby('product_title')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('product_title')
# _ = plt.ylabel('review_headline')
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
# plt.subplots(figsize=(8, 8))
# df_2dhist = pd.DataFrame({
#     x_label: grp['review_body'].value_counts()
#     for x_label, grp in _df_23.groupby('review_headline')
# })
# sns.heatmap(df_2dhist, cmap='viridis')
# plt.xlabel('review_headline')
# _ = plt.ylabel('review_body')
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_24['review_id'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_24, x='customer_id', y='review_id', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_25['product_id'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_25, x='customer_id', y='product_id', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_26['product_title'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_26, x='customer_id', y='product_title', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_27['review_headline'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_27, x='customer_id', y='review_headline', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
print(MobileApps.isnull().sum())
# Out:
# marketplace            0
# customer_id            0
# review_id              0
# product_id             0
# product_parent         0
# product_title          0
# product_category       0
# star_rating            0
# helpful_votes          0
# total_votes            0
# vine                   0
# verified_purchase      0
# review_headline      137
# review_body          245
# review_date           41
# dtype: int64

# %%
MobileApps['review_date'].value_counts().sort_index().plot(figsize=(12,6), title="Number of Reviews Over Time")
plt.xlabel("Date")
plt.ylabel("Number of Reviews")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a12347443c10> in <cell line: 0>()
#       1 MobileApps['review_date'].value_counts().sort_index().plot(figsize=(12,6), title="Number of Reviews Over Time")
# ----> 2 plt.xlabel("Date")
#       3 plt.ylabel("Number of Reviews")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
MobileApps.to_csv('/content/drive/My Drive/AmazonData/MobileApps.csv', index=False)

# %%
Sports.head()
print(Sports.isnull().sum())
Sports_cleaned = Sports.dropna(subset=['star_rating', 'review_body'], how='all')
print(Sports_cleaned.shape)
# Out:
# marketplace            0
# customer_id            0
# review_id              0
# product_id             0
# product_parent         0
# product_title         20
# product_category       0
# star_rating          112
# helpful_votes        156
# total_votes          156
# vine                 156
# verified_purchase    156
# review_headline      211
# review_body          569
# review_date          179
# dtype: int64
# (4832982, 15)

# %%
Sports_cleaned.to_csv('/content/drive/My Drive/AmazonData/Sports.csv', index=False)

# %%
Software.head()
print(Software.isnull().sum())
#Software_cleaned = Sports.dropna(subset=['star_rating', 'review_body'], how='all')
#print(Software_cleaned.shape)
# Out:
# marketplace           0
# customer_id           0
# review_id             0
# product_id            0
# product_parent        0
# product_title        10
# product_category      0
# star_rating           0
# helpful_votes         0
# total_votes           0
# vine                  0
# verified_purchase     0
# review_headline       7
# review_body           9
# review_date           8
# dtype: int64

# %%
Software.to_csv('/content/drive/My Drive/AmazonData/Software.csv', index=False)
